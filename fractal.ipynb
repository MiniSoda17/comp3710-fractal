# %%
import matplotlib.pyplot as plt
import torch

initial_triangle = torch.tensor([[0.0, 0.0], [1.0, 0.0], [0.5, 0.866]]) 
point = torch.tensor([0.5, 0.5])

points_holder = torch.zeros((1000, 2))

for i in range(10000):
    random_vertex = [torch.randint(0, 3, (1,))]
    point = (point + random_vertex) / 2
    points_holder[i] = point

print(points_holder)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 11
#       9 for i in range(10000):
#      10     random_vertex = [torch.randint(0, 3, (1,))]
# ---> 11     point = (point + random_vertex) / 2
#      12     points_holder[i] = point
#      14 print(points_holder)
#
# TypeError: unsupported operand type(s) for +: 'Tensor' and 'list'
